# %%
import pandas as pd

# %%
with open("RES Surrogates.txt", 'r') as file:
    content = file.read()
    lines = content.split('\n')
        
idx = 0
key_str = "The Review of Economic Studies"
titles = list()
doi_links = list()

while idx < len(lines):
    line = lines[idx]
    if key_str not in line:
        idx += 1
        continue
    title = lines[idx - 2]
    
    if title.endswith("Get access Arrow"):
        title = title.removesuffix("Get access Arrow")
    if title.endswith("Open Access"):
        title = title.removesuffix("Open Access")
    if title.endswith("Purchased"):
        title = title.removesuffix("Purchased")

    title = title.strip()
    titles.append(title)
    idx += 1
    start = line.find("https://doi.org/")
    
    end = line.find(" ", start)
    if end == -1:
        doi_link = line[start:]
    else:
        doi_link = line[start:end]
    doi_links.append(doi_link)

df = pd.DataFrame({
    "Title": titles,
    "Link": doi_links
})

# %%
# see if all the titles look right
for title in titles:
    print(title)
# Out:
# The Surrogate Index: Combining Short-Term Proxies to Estimate Long-Term Treatment Effects More Rapidly and Precisely
# Parable and Realism in Capital Theory: The Surrogate Production Function
# Some Notes on the Surrogate Production Function
# Technical Change and the Measurement of Capital and Output
# The Structure of the Cost of Capital under Uncertainty
# Heterogeneous Capital, the Production Function and the Theory of Distribution
# Journal Article
# A Measure of Capital
# The Portfolio Balance Theory of the Expected Rate of Change of Prices: Comment
# Journal Article
# Marginal Productivity and the MacroEconomic Theories of Distribution: Reply to Pasinetti and Robinson
# Information Reliability and a Theory of Financial Intermediation
# A Model of Wage-Price Inflation
# An Asymptotic Theory of Growth Under Uncertainty
# Fundamental Duality Relations in the Pure Theory of Capital and Growth
# The Child Penalty Atlas
# State Preference and the Riskless Interest Rate: A Markov Model of Capital Markets
# The Econometrics of Growth and Underdevelopment: A Test of the Dual Hypotheses
# Notes on the Determinateness of the Utility Function: II
# On the Service Flow from Labour
# The Explanation of Productivity Change
# A Life Cycle Model of Female Labour Supply
# The Factor-Price Frontier, Duality and Joint Production
# Investment and the Optimal Idleness of Capital
# The Demand for Money and Monetary Adjustments in Chile
# Consumer Misperceptions, Product Failure and Producer Liability
# The Short-run Demand for Workers and Hours: A Recursive Model
# The Pasinetti Paradox in Neoclassical and More General Models
# Technical Change and Capital from the Point of View of the Dual
# Empirical Tests for the Existence of Group Utility Functions
# Dynamic Duopoly: Prices and Quantities
# Matching and Bargaining in Dynamic Markets
# Estimation of a Vintage Capital Model for Electricity Generating
# Traditional Capital Theory
# A Two-Level Constant-Elasticity-of-Substitution Production Function
# Disequilibrium Dynamics of Competitive Growth Paths
# The Multiperiod Principal-Agent Problem
# Learning-by-Doing and Infant Industry Protection
# Learning-by-Doing and Infant Industry Protection
# The Duality of Technology and Economic Behaviour
# More Data or Better Data? A Statistical Decision Problem
# Inverse Probability Tilting for Moment Condition Models with Missing Data
# Cross-Border Mergers as Instruments of Comparative Advantage
# Quality Sorting and Trade: Firm-level Evidence for French Wine
# Measuring Diffusion Over a Large Network

# %%
# see if all the links look right
for link in doi_links:
    print(link)
# Out:
# https://doi.org/10.1093/restud/rdaf087
# https://doi.org/10.2307/2295954
# https://doi.org/10.2307/2296520
# https://doi.org/10.2307/2295836
# https://doi.org/10.2307/2296388
# https://doi.org/10.2307/2296729
# https://doi.org/10.1093/restud/29.4.i
# https://doi.org/10.2307/2296320
# https://doi.org/10.2307/2296591
# https://doi.org/10.2307/restud/39.4.i
# https://doi.org/10.2307/2974429
# https://doi.org/10.2307/2297431
# https://doi.org/10.2307/2297105
# https://doi.org/10.2307/2296851
# https://doi.org/10.2307/2296341
# https://doi.org/10.1093/restud/rdae104
# https://doi.org/10.2307/2297012
# https://doi.org/10.2307/2297344
# https://doi.org/10.2307/2967553
# https://doi.org/10.2307/2296738
# https://doi.org/10.2307/2296675
# https://doi.org/10.2307/2297103
# https://doi.org/10.2307/2296494
# https://doi.org/10.2307/2296759
# https://doi.org/10.2307/2296676
# https://doi.org/10.2307/2296908
# https://doi.org/10.2307/2297345
# https://doi.org/10.2307/2974425
# https://doi.org/10.2307/2974405
# https://doi.org/10.2307/2297033
# https://doi.org/10.2307/2297443
# https://doi.org/10.2307/2297527
# https://doi.org/10.2307/2297251
# https://doi.org/10.2307/2296061
# https://doi.org/10.2307/2296809
# https://doi.org/10.2307/2296685
# https://doi.org/10.2307/2297391
# https://doi.org/10.2307/2296497
# https://doi.org/10.2307/2296497
# https://doi.org/10.2307/2296712
# https://doi.org/10.1093/restud/rdx005
# https://doi.org/10.1093/restud/rdr047
# https://doi.org/10.1111/j.1467-937X.2007.00466.x
# https://doi.org/10.1093/restud/rdr030
# https://doi.org/10.1093/restud/rdad115

# %%
print(len(titles))
print(len(doi_links))

# Did we get the right number of results
# Out:
# 45
# 45

# %%
df["Journal"] = "RES"
df["Category"] = "Surrogates"

new_order = ["Journal", "Title", "Link", "Category"]
df = df[new_order]

# %%
df.to_csv("res_surrogates .csv", index=False)
