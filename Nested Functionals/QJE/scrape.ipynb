# %%
import pandas as pd

# %%
with open("QJE Nested Functionals.txt", 'r') as file:
    content = file.read()
    lines = content.split('\n')
    
idx = 0
key_str = "The Quarterly Journal of Economics"
titles = list()
doi_links = list()
dates = list()

while idx < len(lines):
    line = lines[idx]
    if key_str not in line:
        idx += 1
        continue
    
    title = lines[idx - 2]
    date_line = lines[idx + 1]
    date_line_words = date_line.split()
    date = date_line_words[-1]
    
    titles.append(title)
    idx += 1
    start = line.find("https://doi.org/")
    
    end = line.find(" ", start)
    if end == -1:
        doi_link = line[start:]
    else:
        doi_link = line[start:end]
    doi_links.append(doi_link)
    
    dates.append(date)

df = pd.DataFrame({
    "Title": titles,
    "Link": doi_links,
    "Year": dates
})

# %%
print(len(titles))
print(len(doi_links))

# Did we get the right number of results
# Out:
# 208
# 208

# %%
df["Journal"] = "QJE"
df["Category"] = "Nested Functionals"

new_order = ["Journal", "Title", "Link", "Category", "Year"]
df = df[new_order]

# %%
df.to_csv("qje_nested_functionals.csv", index=False)
