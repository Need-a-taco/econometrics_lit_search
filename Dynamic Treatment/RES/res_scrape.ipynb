# %%
import pandas as pd

# %%
with open("RES Dynamic Treatment.txt", 'r') as file:
    content = file.read()
    lines = content.split('\n')
        
idx = 0
key_str = "Review of Economic Studies"
titles = list()
doi_links = list()
dates = list()

while idx < len(lines):
    line = lines[idx]
    if key_str not in line:
        idx += 1
        continue
    title = lines[idx - 2]
    date_line = lines[idx + 1]
    date_line_words = date_line.split()
    date = date_line_words[-1]
    
    if title.endswith("Get access Arrow"):
        title = title.removesuffix("Get access Arrow")
    if title.endswith("Open Access"):
        title = title.removesuffix("Open Access")

    
    titles.append(title)
    idx += 1
    start = line.find("https://doi.org/")
    
    end = line.find(" ", start)
    if end == -1:
        doi_link = line[start:]
    else:
        doi_link = line[start:end]
    doi_links.append(doi_link)
    
    dates.append(date)

df = pd.DataFrame({
    "Title": titles,
    "Link": doi_links,
    "Year": dates
})

# %%
# see if all the titles look right
for title in titles:
    print(title)
# Out:
# Quick Job Entry or Long-Term Human Capital Development? The Dynamic Effects of Alternative Training Schemes
# Subsidizing Labour Hoarding in Recessions: The Employment and Welfare Effects of Short-time Work
# Job Displacement, Unemployment Benefits and Domestic Violence
# A More Credible Approach to Parallel Trends
# The Causal Impact of Socio-Emotional Skills Training on Educational Success
# Asymptotic Least Squares Estimators for Dynamic Games
# An Instrumental Variable Approach to Dynamic Models
# Revisiting Event-Study Designs: Robust and Efficient Estimation
# Simple Transaction Models, Information and Computing
# Semiparametric Inference in Dynamic Binary Choice Models
# Is the Social Safety Net a Long-Term Investment? Large-Scale Evidence From the Food Stamps Program
# Fines and Financial Wellbeing
# Quasi-Experimental Shift-Share Research Designs
# Investing in Influence: Investors, Portfolio Firms, and Political Giving
# Exploiting Growth Opportunities: The Role of Internal Labour Markets
# Are Executives in Short Supply? Evidence from Death Events
# The Effects of Partial Employment Protection Reforms: Evidence from Italy
# Property Rights, Land Misallocation, and Agricultural Efficiency in China
# Taxes Depress Corporate Borrowing: Evidence from Private Firms
# Understanding the City Size Wage Gap
# Optimal Environmental Targeting in the Amazon Rainforest
# State Building in a Diverse Society
# The Value of Unemployment Insurance

# %%
# see if all the links look right
for link in doi_links:
    print(link)
# Out:
# https://doi.org/10.1093/restud/rds022
# https://doi.org/10.1093/restud/rdac069
# https://doi.org/10.1093/restud/rdaf004
# https://doi.org/10.1093/restud/rdad018
# https://doi.org/10.1093/restud/rdae018
# https://doi.org/10.1111/j.1467-937X.2008.00496.x
# https://doi.org/10.1093/restud/rdac061
# https://doi.org/10.1093/restud/rdae007
# https://doi.org/10.2307/2295735
# https://doi.org/10.1093/restud/rdt050
# https://doi.org/10.1093/restud/rdad063
# https://doi.org/10.1093/restud/rdae111
# https://doi.org/10.1093/restud/rdab030
# https://doi.org/10.1093/restud/rdag010
# https://doi.org/10.1093/restud/rdad094
# https://doi.org/10.1093/restud/rdad027
# https://doi.org/10.1093/restud/rdad012
# https://doi.org/10.1093/restud/rdaa072
# https://doi.org/10.1093/restud/rdaf094
# https://doi.org/10.1093/restud/rdr022
# https://doi.org/10.1093/restud/rdac064
# https://doi.org/10.1093/restud/rdae116
# https://doi.org/10.1093/restud/rdaa086

# %%
print(len(titles))
print(len(doi_links))

# Did we get the right number of results
# Out:
# 23
# 23

# %%
df["Journal"] = "RES"
df["Category"] = "Dynamic Treatment"

new_order = ["Journal", "Title", "Link", "Category", "Year"]
df = df[new_order]

# %%
df.to_csv("res_dynamic_treatment.csv", index=False)
