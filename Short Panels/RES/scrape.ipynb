# %%
import pandas as pd

# %%
with open("RES Short Panels.txt", 'r') as file:
    content = file.read()
    lines = content.split('\n')
        
idx = 0
key_str = "The Review of Economic Studies"
titles = list()
doi_links = list()
dates = list()

while idx < len(lines):
    line = lines[idx]
    if key_str not in line:
        idx += 1
        continue
    title = lines[idx - 2]
    date_line = lines[idx + 1]
    date_line_words = date_line.split()
    date = date_line_words[-1]
    
    if title.endswith("Get access Arrow"):
        title = title.removesuffix("Get access Arrow")
    if title.endswith("Open Access"):
        title = title.removesuffix("Open Access")

    titles.append(title)
    idx += 1
    start = line.find("https://doi.org/")
    
    end = line.find(" ", start)
    if end == -1:
        doi_link = line[start:]
    else:
        doi_link = line[start:end]
    doi_links.append(doi_link)
    
    dates.append(date)

df = pd.DataFrame({
    "Title": titles,
    "Link": doi_links,
    "Year": dates
})

# %%
# see if all the titles look right
for title in titles:
    print(title)
# Out:
# Estimating Distributed Lags in Short Panels with an Application to the Specification of Depreciation Patterns and Capital Stock Constructs
# Assessing the Equalizing Force of Mobility Using Short Panels: France, 1990–2000
# The Effect of Work Experience on Female Wages and Labour Supply
# Orthogonal Parameters and Panel Data
# Estimating Intertemporal Allocation Parameters using Synthetic Residual Estimation
# Journal Article
# Estimation with Aggregate Shocks
# Testing for Autocorrelation in Dynamic Random Effects Models
# Split-panel Jackknife Estimation of Fixed-effect Models
# Revisiting Event-Study Designs: Robust and Efficient Estimation
# Demand and Welfare Analysis in Discrete Choice Models with Social Interactions
# Estimating Production Functions Using Inputs to Control for Unobservables
# Identification and Panel Data Models with Endogenous Regressors
# Deforestation in the Amazon: A Unified Framework for Estimation and Policy Analysis
# Dynamic Labour Force Participation of Married Women and Endogenous Work Experience
# Immigration, Wages, and Education: A Labour Market Equilibrium Structural Model
# Identifying Sorting—In Theory
# Claim Timing and Ex Post Adverse Selection
# Political Competition, Policy and Growth: Theory and Evidence from the US
# Farther on down the Road: Transport Costs, Trade and Urban Growth in Sub-Saharan Africa
# International Trade and Currency Exchange
# Estimating the Costs of Standardization: Evidence from the Movie Industry
# Back to Basics: Basic Research Spillovers, Innovation Policy, and Growth
# R&D and Productivity: Estimating Endogenous Productivity
# Identifying Network Ties from Panel Data: Theory and an Application to Tax Competition
# Journal Article
# Political Cycles in OECD Economies
# Market Share, Market Value and Innovation in a Panel of British Manufacturing Firms
# Monetary Policy when Households have Debt: New Evidence on the Transmission Mechanism
# Does Income Inequality Lead to Consumption Inequality? Evidence and Theory
# Household Intertemporal Behaviour: A Collective Characterization and a Test of Commitment
# Education and the Margins of Cyclical Adjustment in the Labor Market
# Quasi-Experimental Shift-Share Research Designs
# Which Investors Matter for Equity Valuations and Expected Returns?
# The Real Effects of Monetary Expansions: Evidence from a Large-scale Historical Experiment
# Globalization and the Ladder of Development: Pushed to the Top or Held at the Bottom?
# The Lifetime Costs of Bad Health
# Subsidizing Labour Hoarding in Recessions: The Employment and Welfare Effects of Short-time Work
# Tax Policy and Lumpy Investment Behaviour: Evidence from China’s VAT Reform
# Religion, Education, and the State

# %%
# see if all the links look right
for link in doi_links:
    print(link)
# Out:
# https://doi.org/10.2307/2297690
# https://doi.org/10.1111/j.1467-937X.2008.00521.x
# https://doi.org/10.1111/1467-937X.00035
# https://doi.org/10.1111/1467-937X.t01-1-00025
# https://doi.org/10.1111/j.1467-937X.2010.00607.x
# https://doi.org/10.2307/restud/51.4.701
# https://doi.org/10.1093/restud/rdz016
# https://doi.org/10.2307/2297546
# https://doi.org/10.1093/restud/rdv007
# https://doi.org/10.1093/restud/rdae007
# https://doi.org/10.1093/restud/rdad053
# https://doi.org/10.1111/1467-937X.00246
# https://doi.org/10.2307/2298050
# https://doi.org/10.1093/restud/rdy070
# https://doi.org/10.2307/2297553
# https://doi.org/10.1093/restud/rdx053
# https://doi.org/10.1093/restud/rdq034
# https://doi.org/10.1093/restud/rdw022
# https://doi.org/10.1111/j.1467-937X.2010.00606.x
# https://doi.org/10.1093/restud/rdw020
# https://doi.org/10.1111/1467-937X.00176
# https://doi.org/10.1093/restud/rdac036
# https://doi.org/10.1093/restud/rdaa061
# https://doi.org/10.1093/restud/rdt011
# https://doi.org/10.1093/restud/rdae088
# https://doi.org/10.1093/restud/56.4.1
# https://doi.org/10.2307/2297992
# https://doi.org/10.1111/1467-937X.00097
# https://doi.org/10.1093/restud/rdy074
# https://doi.org/10.1111/j.1467-937X.2006.00373.x
# https://doi.org/10.1111/j.1467-937X.2007.00447.x
# https://doi.org/10.1093/restud/rdag002
# https://doi.org/10.1093/restud/rdab030
# https://doi.org/10.1093/restud/rdad083
# https://doi.org/10.1093/restud/rdab042
# https://doi.org/10.1093/restud/rdaf077
# https://doi.org/10.1093/restud/rdae080
# https://doi.org/10.1093/restud/rdac069
# https://doi.org/10.1093/restud/rdac027
# https://doi.org/10.1093/restud/rdaf071

# %%
print(len(titles))
print(len(doi_links))

# Did we get the right number of results
# Out:
# 40
# 40

# %%
df["Journal"] = "RES"
df["Category"] = "Short Panels"

new_order = ["Journal", "Title", "Link", "Category", "Year"]
df = df[new_order]

# %%
df.to_csv("res_short_panels.csv", index=False)
