# %%
import pandas as pd

# %%
with open("QJE Short Panels.txt", 'r') as file:
    content = file.read()
    lines = content.split('\n')
        
idx = 0
key_str = "The Quarterly Journal of Economics"
titles = list()
doi_links = list()

while idx < len(lines):
    line = lines[idx]
    if key_str not in line:
        idx += 1
        continue
    title = lines[idx - 2]
    
    if title.endswith("Get access Arrow"):
        title = title.removesuffix("Get access Arrow")
    if title.endswith("Open Access"):
        title = title.removesuffix("Open Access ")

    
    titles.append(title)
    idx += 1
    start = line.find("https://doi.org/")
    
    end = line.find(" ", start)
    if end == -1:
        doi_link = line[start:]
    else:
        doi_link = line[start:end]
    doi_links.append(doi_link)

df = pd.DataFrame({
    "Title": titles,
    "Link": doi_links
})

# %%
# see if all the titles look right
for title in titles:
    print(title)
# Out:
# Manufacturing Revolutions: Industrial Policy and Industrialization in South Korea Open Access
# Job Mobility and the Careers of Young Men Purchased
# Testing the Response of Consumption to Income Changes with (Noisy) Panel Data Purchased
# Do Labor Market Opportunities Affect Young Women's Work and Family Decisions? Experimental Evidence from India Purchased
# The Creation and Capture of Rents: Wages and Innovation in a Panel of U. K. Companies Purchased
# Unconditional Convergence in Manufacturing Purchased
# Radio's Impact on Public Spending Purchased
# The Impact of Young Workers on the Aggregate Labor Market Purchased
# Dividend Taxes and Corporate Behavior: Evidence from the 2003 Dividend Tax Cut Purchased
# A Theory of Wage and Promotion Dynamics Inside Firms Purchased
# Fight or Flight? Portfolio Rebalancing by Individual Investors Purchased
# The Rise of Domestic Outsourcing and the Evolution of the German Wage Structure Purchased
# Decision Making Under the Gambler’s Fallacy: Evidence from Asylum Judges, Loan Officers, and Baseball Umpires Open Access
# Socially Optimal Districting: A Theoretical and Empirical Exploration Purchased
# The Geography of Unemployment Purchased

# %%
# see if all the links look right
for link in doi_links:
    print(link)
# Out:
# https://doi.org/10.1093/qje/qjaf025
# https://doi.org/10.2307/2118478
# https://doi.org/10.2307/1885065
# https://doi.org/10.1093/qje/qjs002
# https://doi.org/10.2307/2946662
# https://doi.org/10.1093/qje/qjs047
# https://doi.org/10.1162/003355304772839560
# https://doi.org/10.1162/00335530152466287
# https://doi.org/10.1093/qje/120.3.791
# https://doi.org/10.1162/003355399556287
# https://doi.org/10.1162/qjec.2009.124.1.301
# https://doi.org/10.1093/qje/qjx008
# https://doi.org/10.1093/qje/qjw017
# https://doi.org/10.1162/qjec.2007.122.4.1409
# https://doi.org/10.1093/qje/qjad010

# %%
print(len(titles))
print(len(doi_links))

# Did we get the right number of results
# Out:
# 15
# 15

# %%
df["Journal"] = "QJE"
df["Category"] = "Short Panels"

new_order = ["Journal", "Title", "Link", "Category"]
df = df[new_order]

# %%
df.to_csv("qje_short_panels.csv", index=False)
